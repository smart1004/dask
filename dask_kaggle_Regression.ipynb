# %%
# https://www.kaggle.com/puneetgrover/speed-up-your-algorithms-dask
# dask_kaggle_Regression

# %%
from dask_ml.datasets import make_regression
import dask.dataframe as dd

X, y = make_regression(n_samples=1e6, chunks=50000)

# %%
df = dd.from_dask_array(X)
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.280883  1.337439 -0.973127 -0.132735  0.118147  0.521227 -0.292070
# 1 -1.157638  0.223525  0.469316  0.449598 -0.170767  0.121935 -0.365619
# 2  0.048516  0.623233 -0.119662  1.948789  1.144257  0.272607  0.695794
# 3  0.793448 -2.037501 -0.666964 -0.874730 -1.938124 -1.722863 -0.230804
# 4  0.452748  1.072103  1.133794  0.190952 -1.065444  0.016702 -1.075068
#
#          7         8         9     ...           90        91        92  \
# 0  0.775049  0.557515  2.291183    ...     0.060717 -1.188204 -0.550006
# 1  0.511680  0.989361 -1.252357    ...    -0.151333 -1.535151  1.075549
# 2  1.296752 -1.390838 -1.439660    ...     0.906040  1.402116  0.365646
# 3  0.441986  1.589245 -0.998076    ...     0.137888  0.916411  0.891575
# 4  1.086373 -1.031330 -2.226748    ...    -0.305742  0.149086 -0.849923
#
#          93        94        95        96        97        98        99
# 0  0.347391 -1.005857 -0.530099  1.782557  2.665641 -0.820064  0.882254
# 1 -0.498816 -0.763169 -1.043308  0.368626 -1.062394 -1.535103  2.793409
# 2  1.576792 -1.520571 -1.235082 -0.310647 -1.933390 -0.406139  0.832234
# 3  1.191007  0.160340 -0.624088  0.156384  0.626258  0.913746  1.005330
# 4  0.130035 -0.736551 -0.528815 -0.956180  0.953712  1.941375 -0.958771
#
# [5 rows x 100 columns]

# %%
from dask_ml.model_selection import train_test_split, GridSearchCV

xtr, ytr, xval, yval = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-0ac9caa05612> in <module>()
#       1 from dask_ml.model_selection import train_test_split, GridSearchCV
#       2
# ----> 3 xtr, ytr, xval, yval = train_test_split(X, y)
#
# c:\programdata\psc_env\lib\site-packages\dask_ml\model_selection\_split.py in train_test_split(*arrays, **options)
#     448             random_state=random_state,
#     449         )
# --> 450         train_idx, test_idx = next(splitter.split(*arrays))
#     451
#     452         train_test_pairs = (
#
# c:\programdata\psc_env\lib\site-packages\dask_ml\model_selection\_split.py in split(self, X, y, groups)
#     155         rng = check_random_state(self.random_state)
#     156         for i in range(self.n_splits):
# --> 157             seeds = draw_seed(rng, 0, 2 ** 32 - 1, size=len(X.chunks[0]), dtype="uint")
#     158             if self.blockwise:
#     159                 yield self._split_blockwise(X, seeds)
#
# c:\programdata\psc_env\lib\site-packages\dask_ml\_utils.py in draw_seed(random_state, low, high, size, dtype, chunks)
#      15         kwargs["chunks"] = chunks
#      16
# ---> 17     seed = random_state.randint(low, high, **kwargs)
#      18     if dtype is not None and isinstance(seed, (da.Array, np.ndarray)):
#      19         seed = seed.astype(dtype)
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: high is out of bounds for int32
